# %%
pip install pyspark
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("DataPipelineProject") \
    .getOrCreate()

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Replace <password> with your actual password
uri = "mongodb+srv://AdityaK:29%40Aditya10@cluster0.ceyemcy.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Replace <password> with your actual password
uri = "mongodb+srv://AdityaK:29%40Aditya10@cluster0.ceyemcy.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# List all databases
print("Databases:")
databases = client.list_database_names()
for db in databases:
    print(f"- {db}")

# Access a specific database and collection
db = client['Canada_disaster_json']
collection = db['Canada_disaster_database']

# Insert a document
doc = {"name": "Test Document", "value": 123}
insert_result = collection.insert_one(doc)
print(f"Inserted document ID: {insert_result.inserted_id}")

# Read documents
print("Documents in collection:")
for document in collection.find():
    print(document)

# Update a document
update_result = collection.update_one({"name": "Test Document"}, {"$set": {"value": 456}})
print(f"Matched {update_result.matched_count} document(s) and modified {update_result.modified_count} document(s).")

# Delete a document
delete_result = collection.delete_one({"name": "Test Document"})
print(f"Deleted {delete_result.deleted_count} document(s).")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Databases:
# - Canada_disaster_json
# - admin
# - local
# Inserted document ID: 668c9bc3bbe03754f415e9f9
# Documents in collection:
# ...
